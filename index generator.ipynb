# %%
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook

# %%
df_link_id = pd.read_csv('input.csv', sep='\t')

INDEX = 1
cur = df_link_id[df_link_id['INDEX'] == INDEX]
INDEX = INDEX + 1

while df_link_id['INDEX'].isna().sum() > 0:
    to = df_link_id[(df_link_id['INDEX'].isna()) & (df_link_id['tF_ID'] == cur['tT_ID'].item())]
    if len(to) > 1:
        temp = to
        to = to[to['tT_ID'] != cur['tF_ID'].item()]
        if len(to) == 0:
            to = temp
        if len(to) > 1:
            print(df_link_id[df_link_id['INDEX'].notna()].sort_values('INDEX')[['F_ID', 'LINK_ID', 'T_ID', '노선ID', '노선번호', 'INDEX']])
            print(to[['F_ID', 'LINK_ID', 'T_ID', '노선ID', '노선번호', 'INDEX']])
            rid = int(input('ROW_ID: '))
            to = to[to.index == rid]
        df_link_id.at[to.index, 'INDEX'] = INDEX
    else:
        df_link_id.at[df_link_id[(df_link_id['INDEX'].isna()) & (df_link_id['tF_ID'] == cur['tT_ID'].item())].index, 'INDEX'] = INDEX
        to = df_link_id[df_link_id['INDEX'] == INDEX]
#     print(cur)
    INDEX = INDEX + 1
    cur = to
#     print(to)
    
df_link_id.sort_values('INDEX').to_csv('output.csv', index=False, encoding='utf-8-sig')
# Out:
#           F_ID     LINK_ID        T_ID  노선ID       노선번호  INDEX
# 83  1690015300  1690040400  1690015200   NaN  61(강화)_신설    1.0
# 50  1690015200  1690040200  1690009500   NaN  61(강화)_신설    2.0
#           F_ID     LINK_ID        T_ID  노선ID       노선번호  INDEX
# 28  1690009500  1690106800  1690034700   NaN  61(강화)_신설    NaN
# 79  1690009500  1690000400  1690009400   NaN  61(강화)_신설    NaN
# ROW_ID: 79
#           F_ID     LINK_ID        T_ID  노선ID       노선번호  INDEX
# 83  1690015300  1690040400  1690015200   NaN  61(강화)_신설    1.0
# 50  1690015200  1690040200  1690009500   NaN  61(강화)_신설    2.0
# 79  1690009500  1690000400  1690009400   NaN  61(강화)_신설    3.0
# 63  1690009400  1690003800  1690020100   NaN  61(강화)_신설    4.0
# 43  1690020100  1690053100  1690001600   NaN  61(강화)_신설    5.0
# 65  1690001600  1690003400  1690001500   NaN  61(강화)_신설    6.0
# 67  1690001500  1690003200  1690001400   NaN  61(강화)_신설    7.0
# 69  1690001400  1690003000  1690001300   NaN  61(강화)_신설    8.0
# 71  1690001300  1690002600  1690001100   NaN  61(강화)_신설    9.0
# 81  1690001100  1690000200  1690049100   NaN  61(강화)_신설   10.0
# 16  1690049100  1690132800  1690049200   NaN  61(강화)_신설   11.0
# 14  1690049200  1690133000  1690000600   NaN  61(강화)_신설   12.0
# 73  1690000600  1690002200  1690001000   NaN  61(강화)_신설   13.0
# 75  1690001000  1690002000  1690000900   NaN  61(강화)_신설   14.0
# 33  1690000900  1690101900  1690042400   NaN  61(강화)_신설   15.0
# 36  1690042400  1690097600  1690050700   NaN  61(강화)_신설   16.0
# 10  1690050700  1690136000  1690050600   NaN  61(강화)_신설   17.0
# 12  1690050600  1690135800  1690000800   NaN  61(강화)_신설   18.0
# 77  1690000800  1690001600  1690019900   NaN  61(강화)_신설   19.0
# 45  1690019900  1690052700  1690000700   NaN  61(강화)_신설   20.0
# 30  1690000700  1690106400  1690000500   NaN  61(강화)_신설   21.0
# 35  1690000500  1690101500  1690041100   NaN  61(강화)_신설   22.0
# 18  1690041100  1690132600  1690006000   NaN  61(강화)_신설   23.0
# 60  1690006000  1690019400  1690006100   NaN  61(강화)_신설   24.0
# 26  1690006100  1690108700  1690031400   NaN  61(강화)_신설   25.0
